# %%
#Import libraries and data
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('Video_Games.csv')

# %%
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# ...

# %%
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# ...

# %%
duplicated = df.duplicated().sum()
print(f'Number of rows duplicated: {duplicated}')
# Out:
# Number of rows duplicated: 0

# %%
df['User_Score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
#Convert to proper data type
df['Year_of_Release']=df['Year_of_Release'].astype('Int64')
df['Critic_Score']=df['Critic_Score'].astype('Int64')
df['Critic_Count']=df['Critic_Count'].astype('Int64')
df['User_Count']=df['User_Count'].astype('Int64')
df['User_Score'] = pd.to_numeric(df['User_Score'], errors= 'coerce')

# %%
#Check if values are of the float datatype now
df['User_Score'].unique()
# Out:
# array([8. , nan, 8.3, 8.5, 6.6, 8.4, 8.6, 7.7, 6.3, 7.4, 8.2, 9. , 7.9,
#        8.1, 8.7, 7.1, 3.4, 5.3, 4.8, 3.2, 8.9, 6.4, 7.8, 7.5, 2.6, 7.2,
#        9.2, 7. , 7.3, 4.3, 7.6, 5.7, 5. , 9.1, 6.5, 8.8, 6.9, 9.4, 6.8,
#        6.1, 6.7, 5.4, 4. , 4.9, 4.5, 9.3, 6.2, 4.2, 6. , 3.7, 4.1, 5.8,
#        5.6, 5.5, 4.4, 4.6, 5.9, 3.9, 3.1, 2.9, 5.2, 3.3, 4.7, 5.1, 3.5,
#        2.5, 1.9, 3. , 2.7, 2.2, 2. , 9.5, 2.1, 3.6, 2.8, 1.8, 3.8, 0. ,
#        1.6, 9.6, 2.4, 1.7, 1.1, 0.3, 1.5, 0.7, 1.2, 2.3, 0.5, 1.3, 0.2,
#        0.6, 1.4, 0.9, 1. , 9.7])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  Int64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   Int64
#  11  Critic_Count     8137 non-null   Int64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   Int64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# ...

# %%
df=df.sort_values('Year_of_Release')

# %%
df
# Out:
#                                     Name Platform  Year_of_Release  \
# 2650                              Boxing     2600             1980
# 1968                            Defender     2600             1980
# 6301                              Bridge     2600             1980
# 1764                             Kaboom!     2600             1980
# 6876                            Checkers     2600             1980
# ...                                  ...      ...              ...
# 16376  PDC World Championship Darts 2008      PSP             <NA>
# 16409                      Freaky Flyers       GC             <NA>
# 16452                          Inversion       PC             <NA>
# 16462        Hakuouki: Shinsengumi Kitan      PS3             <NA>
# 16526                       Virtua Quest       GC             <NA>
#
#               Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 2650       Fighting          Activision      0.72      0.04       0.0
# ...

# %%
sales_per_year = df.groupby('Year_of_Release')[['NA_Sales', 'EU_Sales', 'JP_Sales']].sum().reset_index()
sales_per_year.astype('int64')
# Out:
#     Year_of_Release  NA_Sales  EU_Sales  JP_Sales
# 0              1980        10         0         0
# 1              1981        33         1         0
# 2              1982        26         1         0
# 3              1983         7         0         8
# 4              1984        33         2        14
# 5              1985        33         4        14
# 6              1986        12         2        19
# 7              1987         8         1        11
# 8              1988        23         6        15
# 9              1989        45         8        18
# 10             1990        25         7        14
# 11             1991        12         3        14
# 12             1992        33        11        28
# 13             1993        16         5        25
# 14             1994        28        14        33
# 15             1995        24        14        45
# 16             1996        86        47        57
# 17             1997        94        48        48
# ...

# %%
sales_per_year.columns
# Out:
# Index(['Year_of_Release', 'NA_Sales', 'EU_Sales', 'JP_Sales'], dtype='object')

# %%
plt.figure(figsize=(10,6))
plt.plot(sales_per_year['Year_of_Release'], sales_per_year['NA_Sales'], label = 'NA_Sales')
plt.plot(sales_per_year['Year_of_Release'], sales_per_year['EU_Sales'], label = 'EU_Sales')
plt.plot(sales_per_year['Year_of_Release'], sales_per_year['JP_Sales'], label = 'JP_Sales')
plt.title('Sales per Region')
plt.legend()
plt.show()

# %%
games_per_year = df.groupby('Year_of_Release').size()
pd.reset_option('display.max_rows', None)
games_per_year.values
# Out:
# array([   9,   46,   36,   17,   14,   14,   21,   16,   15,   17,   16,
#          41,   43,   62,  121,  219,  263,  289,  379,  338,  350,  482,
#         829,  775,  762,  939, 1006, 1197, 1427, 1426, 1255, 1136,  653,
#         544,  581,  606,  502,    3,    1])

# %%
games_per_year
# Out:
# Year_of_Release
# 1980       9
# 1981      46
# 1982      36
# 1983      17
# 1984      14
# 1985      14
# 1986      21
# 1987      16
# 1988      15
# 1989      17
# 1990      16
# 1991      41
# 1992      43
# 1993      62
# 1994     121
# 1995     219
# 1996     263
# 1997     289
# 1998     379
# 1999     338
# 2000     350
# 2001     482
# 2002     829
# 2003     775
# 2004     762
# 2005     939
# 2006    1006
# 2007    1197
# 2008    1427
# 2009    1426
# 2010    1255
# 2011    1136
# 2012     653
# 2013     544
# 2014     581
# 2015     606
# 2016     502
# 2017       3
# 2020       1
# dtype: int64

# %%
sales_per_year['total_sales'] = sales_per_year[['NA_Sales'] + ['EU_Sales'] + ['JP_Sales']].sum(axis=1)
sales_per_year = sales_per_year.set_index('Year_of_Release')
sales_per_year
# Out:
#                  NA_Sales  EU_Sales  JP_Sales  total_sales
# Year_of_Release
# 1980                10.59      0.67      0.00        11.26
# 1981                33.40      1.96      0.00        35.36
# 1982                26.92      1.65      0.00        28.57
# 1983                 7.76      0.80      8.10        16.66
# 1984                33.28      2.10     14.27        49.65
# 1985                33.73      4.74     14.56        53.03
# 1986                12.50      2.84     19.81        35.15
# 1987                 8.46      1.41     11.63        21.50
# 1988                23.87      6.59     15.76        46.22
# 1989                45.15      8.44     18.36        71.95
# 1990                25.46      7.63     14.88        47.97
# 1991                12.76      3.95     14.78        31.49
# 1992                33.89     11.71     28.91        74.51
# 1993                16.90      5.18     25.36        47.44
# 1994                28.16     14.88     33.99        77.03
# ...

# %%
games_per_year_df = games_per_year.to_frame(name= 'num_of_games')

games_per_year_df['total_sales'] = sales_per_year[['NA_Sales'] + ['EU_Sales'] + ['JP_Sales']].sum(axis=1)
games_per_year_df
# Out:
#                  num_of_games  total_sales
# Year_of_Release
# 1980                        9        11.26
# 1981                       46        35.36
# 1982                       36        28.57
# 1983                       17        16.66
# 1984                       14        49.65
# 1985                       14        53.03
# 1986                       21        35.15
# 1987                       16        21.50
# 1988                       15        46.22
# 1989                       17        71.95
# 1990                       16        47.97
# 1991                       41        31.49
# 1992                       43        74.51
# 1993                       62        47.44
# 1994                      121        77.03
# 1995                      219        85.48
# 1996                      263       191.46
# 1997                      289       191.94
# 1998                      379       245.30
# 1999                      338       241.07
# ...

# %%
games_per_year_df[['num_of_games', 'total_sales']].plot(kind='line', figsize = (12, 6), grid = True)
# Out:
# <Axes: xlabel='Year_of_Release'>

# %%
df = df[df['Year_of_Release'] < 2010]
sales_per_year = sales_per_year.reset_index()

# %%
sales_per_year = sales_per_year[sales_per_year['Year_of_Release'] < 2010] 
sales_per_year = sales_per_year.drop('total_sales', axis = 1)
sales_per_year
# Out:
#     Year_of_Release  NA_Sales  EU_Sales  JP_Sales
# 0              1980     10.59      0.67      0.00
# 1              1981     33.40      1.96      0.00
# 2              1982     26.92      1.65      0.00
# 3              1983      7.76      0.80      8.10
# 4              1984     33.28      2.10     14.27
# 5              1985     33.73      4.74     14.56
# 6              1986     12.50      2.84     19.81
# 7              1987      8.46      1.41     11.63
# 8              1988     23.87      6.59     15.76
# 9              1989     45.15      8.44     18.36
# 10             1990     25.46      7.63     14.88
# 11             1991     12.76      3.95     14.78
# 12             1992     33.89     11.71     28.91
# 13             1993     16.90      5.18     25.36
# 14             1994     28.16     14.88     33.99
# 15             1995     24.83     14.90     45.75
# 16             1996     86.76     47.26     57.44
# 17             1997     94.75     48.32     48.87
# ...

# %%
df.tail()
# Out:
#                                                     Name Platform  \
# 16643            WSC REAL 09: World Snooker Championship      PS3
# 16646  Hirameki Action: Chibikko Wagyan no Daiki na B...       DS
# 4472                                           Band Hero       DS
# 16654                Agatha Christie: Peril at End House       PC
# 8                              New Super Mario Bros. Wii      Wii
#
#        Year_of_Release      Genre           Publisher  NA_Sales  EU_Sales  \
# 16643             2009     Sports         Deep Silver      0.00      0.01
# 16646             2009     Action  Namco Bandai Games      0.00      0.00
# 4472              2009       Misc          Activision      0.20      0.19
# 16654             2009  Adventure  JoWood Productions      0.00      0.01
# 8                 2009   Platform            Nintendo     14.44      6.94
#
#        JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# ...

# %%
sales_per_year
# Out:
#     Year_of_Release  NA_Sales  EU_Sales  JP_Sales
# 0              1980     10.59      0.67      0.00
# 1              1981     33.40      1.96      0.00
# 2              1982     26.92      1.65      0.00
# 3              1983      7.76      0.80      8.10
# 4              1984     33.28      2.10     14.27
# 5              1985     33.73      4.74     14.56
# 6              1986     12.50      2.84     19.81
# 7              1987      8.46      1.41     11.63
# 8              1988     23.87      6.59     15.76
# 9              1989     45.15      8.44     18.36
# 10             1990     25.46      7.63     14.88
# 11             1991     12.76      3.95     14.78
# 12             1992     33.89     11.71     28.91
# 13             1993     16.90      5.18     25.36
# 14             1994     28.16     14.88     33.99
# 15             1995     24.83     14.90     45.75
# 16             1996     86.76     47.26     57.44
# 17             1997     94.75     48.32     48.87
# ...

# %%
plt.figure(figsize=(10,6))
plt.plot(sales_per_year['Year_of_Release'], sales_per_year['NA_Sales'], label = 'NA_Sales')
plt.plot(sales_per_year['Year_of_Release'], sales_per_year['EU_Sales'], label = 'EU_Sales')
plt.plot(sales_per_year['Year_of_Release'], sales_per_year['JP_Sales'], label = 'JP_Sales')
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'${int(x)}M'))
plt.ylabel('Sales')
plt.title('Sales per Region')
plt.legend()
plt.show()

# %%
df['Publisher'].value_counts()
# Out:
# Publisher
# Electronic Arts                 998
# Activision                      627
# Konami Digital Entertainment    623
# Ubisoft                         607
# THQ                             570
#                                ...
# Valve Software                    1
# TGL                               1
# Genterprise                       1
# G.Rev                             1
# 1C Company                        1
# Name: count, Length: 461, dtype: int64

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize= (10, 6))
df.groupby('Genre')['JP_Sales'].sum().sort_values(ascending=False).plot(kind='bar', ax = ax1)
ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y)}M'))
ax1.set_title('Videogame Sales in Japan by Genre')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45)
for labels in ax1.get_xticklabels():
    labels.set_ha('right')

df.groupby('Rating')['JP_Sales'].sum().sort_values(ascending=False).head(4).plot(kind='bar', ax = ax2)
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y)}M'))
ax2.set_title('Videogame Sales in Japan by Rating')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45)
fig.suptitle('1980-2009', fontsize = 18)
plt.tight_layout()
plt.show()

# %%
fig2, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 6))
df.groupby('Genre')['EU_Sales'].sum().sort_values(ascending= False).plot(kind= 'bar', ax = ax1)
ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y)}M'))
ax1.set_title('Videogame Sales in Europe by Genre')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45)
for labels in ax1.get_xticklabels():
    labels.set_ha('right')

df.groupby('Rating')['EU_Sales'].sum().sort_values(ascending= False).head(4).plot(kind= 'bar', ax = ax2)
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y)}M'))
ax2.set_title('Videogame Sales in Europe by Rating')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45)
fig2.suptitle('1980-2009', fontsize = 18)
plt.tight_layout()
plt.show()

# %%
fig3, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 6))
df.groupby('Genre')['NA_Sales'].sum().sort_values(ascending= False).plot(kind= 'bar', ax = ax1)
ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y)}M'))
ax1.set_title('Videogame Sales in North America by Genre')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45)
for labels in ax1.get_xticklabels():
    labels.set_ha('right')

df.groupby('Rating')['NA_Sales'].sum().sort_values(ascending= False).head(4).plot(kind= 'bar', ax = ax2)
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y)}M'))
ax2.set_title('Videogame Sales in North America by Rating')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45)
fig3.suptitle('1980-2009', fontsize = 18)
plt.tight_layout()
plt.show()
